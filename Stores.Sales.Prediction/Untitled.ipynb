# %%
import pandas as pd
import numpy as np
import seaborn as sns
#import pandas_profiling

# %%
train=pd.read_csv("Train.csv")
test=pd.read_csv("Test.csv")

# %%
train_df=train.copy(deep=True)

# %%
#pfr=pandas_profiling.ProfileReport(df)
#pfr.to_file("Stores.html")

# %%
train_df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train_df[train_df["Item_Identifier"]=="FDG33"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 231            FDG33          NaN          Regular         0.139561   Seafood
# 1202           FDG33        5.365          Regular         0.140525   Seafood
# 1575           FDG33          NaN          Regular         0.245543   Seafood
# 2728           FDG33        5.365          Regular         0.234733   Seafood
# 4747           FDG33        5.365          Regular         0.140458   Seafood
# 5164           FDG33        5.365          Regular         0.140240   Seafood
# 6112           FDG33        5.365          Regular         0.141034   Seafood
# 7011           FDG33        5.365          Regular         0.140812   Seafood
# 7098           FDG33        5.365          Regular         0.140124   Seafood
# 7726           FDG33        5.365          Regular         0.140214   Seafood
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
train_df[train_df["Item_Identifier"]=="FDG33"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 231            FDG33          NaN          Regular         0.139561   Seafood
# 1202           FDG33        5.365          Regular         0.140525   Seafood
# 1575           FDG33          NaN          Regular         0.245543   Seafood
# 2728           FDG33        5.365          Regular         0.234733   Seafood
# 4747           FDG33        5.365          Regular         0.140458   Seafood
# 5164           FDG33        5.365          Regular         0.140240   Seafood
# 6112           FDG33        5.365          Regular         0.141034   Seafood
# 7011           FDG33        5.365          Regular         0.140812   Seafood
# 7098           FDG33        5.365          Regular         0.140124   Seafood
# 7726           FDG33        5.365          Regular         0.140214   Seafood
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
train_df[train_df["Item_Identifier"]=="FDW13"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 256            FDW13          8.5          Low Fat         0.098438    Canned
# 1141           FDW13          8.5          Low Fat         0.097866    Canned
# 2190           FDW13          8.5          Low Fat         0.098283    Canned
# 3928           FDW13          NaN          Low Fat         0.097411    Canned
# 3978           FDW13          8.5          Low Fat         0.098037    Canned
# 6499           FDW13          8.5          Low Fat         0.098083    Canned
# 6587           FDW13          8.5          low fat         0.163839    Canned
# 7029           FDW13          8.5          Low Fat         0.097803    Canned
# 8025           FDW13          NaN          Low Fat         0.171384    Canned
# 8032           FDW13          8.5          Low Fat         0.097885    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
(train_df["Item_Identifier"].unique())
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
dict1={}
type(train_df["Item_Identifier"].unique())
# Out:
# numpy.ndarray

# %%
dict_df=train_df[["Item_Identifier","Item_Weight"]]
dict_df
# Out:
#      Item_Identifier  Item_Weight
# 0              FDA15        9.300
# 1              DRC01        5.920
# 2              FDN15       17.500
# 3              FDX07       19.200
# 4              NCD19        8.930
# ...              ...          ...
# 8518           FDF22        6.865
# 8519           FDS36        8.380
# 8520           NCJ29       10.600
# 8521           FDN46        7.210
# 8522           DRG01       14.800
#
# [8523 rows x 2 columns]

# %%
# Considering feature "Item_Identifier" and its contribution in determining Output Sales

train_df["Item_Identifier"].value_counts()
# Out:
# FDG33    10
# FDW13    10
# NCQ06     9
# FDP25     9
# FDX20     9
#          ..
# FDT35     1
# FDE52     1
# DRF48     1
# FDO33     1
# FDQ60     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
train_df[["Item_Identifier","Item_Outlet_Sales"]]
# Out:
#      Item_Identifier  Item_Outlet_Sales
# 0              FDA15          3735.1380
# 1              DRC01           443.4228
# 2              FDN15          2097.2700
# 3              FDX07           732.3800
# 4              NCD19           994.7052
# ...              ...                ...
# 8518           FDF22          2778.3834
# 8519           FDS36           549.2850
# 8520           NCJ29          1193.1136
# 8521           FDN46          1845.5976
# 8522           DRG01           765.6700
#
# [8523 rows x 2 columns]

# %%
train_df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train_df["Item_Identifier_initials_2"]=train_df["Item_Identifier"].str[:3]

# %%
train_df["Item_Identifier_initials_2"].value_counts()
# Out:
# FDX    295
# FDT    281
# FDS    279
# FDR    275
# FDW    271
#       ...
# DRO     14
# DRP     12
# DRZ     11
# DRQ      7
# DRY      6
# Name: Item_Identifier_initials_2, Length: 71, dtype: int64

# %% [markdown]
# # FEATURE 1:

# %% [markdown]
# ### CHANGE 1:

# %%
train_df["Item_Identifier_initials"]=train_df["Item_Identifier"].str[:2]

# %%
train_df["Item_Identifier_initials"].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: Item_Identifier_initials, dtype: int64

# %%
type(train_df["Item_Identifier_initials"][0])
# Out:
# str

# %%
import seaborn as sns
import matplotlib.pyplot as plt
barplot=sns.barplot(x="Item_Identifier_initials",y="Item_Outlet_Sales",data=train_df)
plt.ylim(0,2500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4bf727a7d93e> in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 barplot=sns.barplot(x="Item_Identifier_initials",y="Item_Outlet_Sales",data=train_df)
#       4 plt.ylim(0,2500)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
barplot=sns.barplot(x="Item_Identifier_initials",y="Item_Outlet_Sales",data=train_df)
plt.ylim(0,3000)
for bar in barplot.patches:
    barplot.annotate(format(bar.get_height(),'.2f'),(bar.get_x()+bar.get_width()/2,bar.get_height()),
                    
                   size=12, xytext=(-15,10),textcoords="offset points")

# %% [markdown]
# # FEATURE 2:

# %%
train_df["Item_Weight"].isnull().sum()
# Out:
# 1463

# %%
train_df.shape
# Out:
# (8523, 14)

# %%
train_df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train_df[["Item_Weight","Item_Identifier"]]
# Out:
#       Item_Weight Item_Identifier
# 0           9.300           FDA15
# 1           5.920           DRC01
# 2          17.500           FDN15
# 3          19.200           FDX07
# 4           8.930           NCD19
# ...           ...             ...
# 8518        6.865           FDF22
# 8519        8.380           FDS36
# 8520       10.600           NCJ29
# 8521        7.210           FDN46
# 8522       14.800           DRG01
#
# [8523 rows x 2 columns]

# %%
rel=pd.DataFrame(columns=["Item_Ident","Weight"])
rel
# Out:
# Empty DataFrame
# Columns: [Item_Ident, Weight]
# Index: []

# %%
uniq=set(train_df["Item_Identifier"].unique())

# %%
for i in train_df["Item_Identifier"].unique(): 
    rel_entry=pd.DataFrame(columns=["Item_Ident","Weight"])

    rel_entry["Weight"]=train_df[["Item_Weight","Item_Identifier"]][train_df["Item_Identifier"]==i]["Item_Weight"]
    rel_entry["Item_Ident"]=i
    rel=rel.append(rel_entry)

# %% [markdown]
# for i in train_df["Item_Identifier"].unique():
#     rel_entry=pd.DataFrame(columns=["Item_Ident","Weight"])
#
#     rel_entry["Weight"]=train_df[["Item_Weight","Item_Identifier"]][train_df["Item_Identifier"]==i]["Item_Weight"]
#     rel_entry["Item_Ident"]=i
#     rel=rel.append(rel_entry)

# %%
rel=rel.drop_duplicates()

# %%
rel=rel.dropna()

# %%
rel
# Out:
#      Item_Ident  Weight
# 0         FDA15   9.300
# 1         DRC01   5.920
# 2         FDN15  17.500
# 3         FDX07  19.200
# 4         NCD19   8.930
# ...         ...     ...
# 6440      FDD28  10.695
# 7421      FDU43  19.350
# 6892      NCF55   6.675
# 7039      NCW30   5.210
# 7298      NCW05  20.250
#
# [1555 rows x 2 columns]

# %%
uniq2=set(rel["Item_Ident"])

# %%
diff=uniq-uniq2
diff
# Out:
# {'FDE52', 'FDK57', 'FDN52', 'FDQ60'}

# %%
train_df[train_df["Item_Identifier"]=='FDE52']
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
train_df=train_df[(train_df.Item_Identifier != 'FDE52') & (train_df.Item_Identifier != 'FDK57') & (train_df.Item_Identifier != 'FDN52') & (train_df.Item_Identifier != 'FDQ60')]

# %%
train_df[train_df["Item_Identifier"]=='FDQ60'  ]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
rel=pd.DataFrame(columns=["Item_Ident","Weight"])
rel
# Out:
# Empty DataFrame
# Columns: [Item_Ident, Weight]
# Index: []

# %%
len(train_df["Item_Identifier"].unique())
# Out:
# 1555

# %%
for i in train_df["Item_Identifier"].unique(): 
    rel_entry=pd.DataFrame(columns=["Item_Ident","Weight"])

    rel_entry["Weight"]=train_df[["Item_Weight","Item_Identifier"]][train_df["Item_Identifier"]==i]["Item_Weight"]
    rel_entry["Item_Ident"]=i
    rel=rel.append(rel_entry)

# %%
rel
# Out:
#      Item_Ident  Weight
# 0         FDA15   9.300
# 831       FDA15   9.300
# 2599      FDA15   9.300
# 2643      FDA15   9.300
# 4874      FDA15   9.300
# ...         ...     ...
# 8135      NCF55   6.675
# 7039      NCW30   5.210
# 7635      NCW30   5.210
# 7298      NCW05  20.250
# 7857      NCW05  20.250
#
# [8519 rows x 2 columns]

# %%
rel=rel.drop_duplicates()

# %%
rel=rel.dropna()

# %%
rel
# Out:
#      Item_Ident  Weight
# 0         FDA15   9.300
# 1         DRC01   5.920
# 2         FDN15  17.500
# 3         FDX07  19.200
# 4         NCD19   8.930
# ...         ...     ...
# 6440      FDD28  10.695
# 7421      FDU43  19.350
# 6892      NCF55   6.675
# 7039      NCW30   5.210
# 7298      NCW05  20.250
#
# [1555 rows x 2 columns]

# %%
len(train_df["Item_Identifier"].unique())
# Out:
# 1555

# %%
train_df[np.isnan(train_df.loc[:,'Item_Weight'])]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %% [raw]
# tnp.isnan(train_df.loc[:,'Item_Weight'])

# %%
pd.isnull(train_df["Item_Weight"][9])
# Out:
# False

# %% [markdown]
# # FEATURE 3:ITEM_FAT_CONTENT

# %%
train_df["Item_Fat_Content"].describe()
# Out:
# count        8523
# unique          5
# top       Low Fat
# freq         5089
# Name: Item_Fat_Content, dtype: object

# %%
train_df["Item_Fat_Content"].isnull().sum()
# Out:
# 0

# %%
sns.barplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=train_df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>
