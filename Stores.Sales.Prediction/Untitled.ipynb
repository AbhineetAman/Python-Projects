# %%
import pandas as pd
#import pandas_profiling

# %%
df=pd.read_csv("Train.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#pfr=pandas_profiling.ProfileReport(df)
#pfr.to_file("Stores.html")

# %%
df[df["Item_Identifier"]=="FDG33"].value_counts()
# Out:
# Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type        Item_Outlet_Sales
# FDG33            5.365        Regular           0.140124         Seafood    172.0764  OUT013             1987                       High         Tier 3                Supermarket Type1  2748.4224            1
#                                                 0.140214         Seafood    173.7764  OUT035             2004                       Small        Tier 2                Supermarket Type1  4637.9628            1
#                                                 0.140240         Seafood    171.0764  OUT046             1997                       Small        Tier 1                Supermarket Type1  3263.7516            1
# ...

# %%
df[df["Item_Identifier"]=="FDG33"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 231            FDG33          NaN          Regular         0.139561   Seafood
# 1202           FDG33        5.365          Regular         0.140525   Seafood
# 1575           FDG33          NaN          Regular         0.245543   Seafood
# 2728           FDG33        5.365          Regular         0.234733   Seafood
# 4747           FDG33        5.365          Regular         0.140458   Seafood
# 5164           FDG33        5.365          Regular         0.140240   Seafood
# 6112           FDG33        5.365          Regular         0.141034   Seafood
# 7011           FDG33        5.365          Regular         0.140812   Seafood
# 7098           FDG33        5.365          Regular         0.140124   Seafood
# 7726           FDG33        5.365          Regular         0.140214   Seafood
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
df[df["Item_Identifier"]=="FDW13"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 256            FDW13          8.5          Low Fat         0.098438    Canned
# 1141           FDW13          8.5          Low Fat         0.097866    Canned
# 2190           FDW13          8.5          Low Fat         0.098283    Canned
# 3928           FDW13          NaN          Low Fat         0.097411    Canned
# 3978           FDW13          8.5          Low Fat         0.098037    Canned
# 6499           FDW13          8.5          Low Fat         0.098083    Canned
# 6587           FDW13          8.5          low fat         0.163839    Canned
# 7029           FDW13          8.5          Low Fat         0.097803    Canned
# 8025           FDW13          NaN          Low Fat         0.171384    Canned
# 8032           FDW13          8.5          Low Fat         0.097885    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
(df["Item_Identifier"].unique())
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
dict1={}
type(df["Item_Identifier"].unique())
# Out:
# numpy.ndarray

# %%
dict_df=df[["Item_Identifier","Item_Weight"]]
dict_df
# Out:
#      Item_Identifier  Item_Weight
# 0              FDA15        9.300
# 1              DRC01        5.920
# 2              FDN15       17.500
# 3              FDX07       19.200
# 4              NCD19        8.930
# ...              ...          ...
# 8518           FDF22        6.865
# 8519           FDS36        8.380
# 8520           NCJ29       10.600
# 8521           FDN46        7.210
# 8522           DRG01       14.800
#
# [8523 rows x 2 columns]

# %%
df[df["Item_Identifier"].unique()==x]['Item_Weight']
# Out:
# 0       9.3
# 831     9.3
# 2599    9.3
# 2643    9.3
# 4874    9.3
# 5413    9.3
# 6696    NaN
# 7543    9.3
# Name: Item_Weight, dtype: float64

# %%
d2={x:df[df["Item_Identifier"]==x]['Item_Weight']  for x in (df["Item_Identifier"].unique()) }

# %%
d2
# Out:
# {'FDA15': 0       9.3
#  831     9.3
#  2599    9.3
#  2643    9.3
#  4874    9.3
#  5413    9.3
#  6696    NaN
#  7543    9.3
#  Name: Item_Weight, dtype: float64,
#  'DRC01': 1       5.92
#  2272    5.92
#  2927     NaN
#  5029    5.92
#  5077    5.92
#  5218    5.92
#  Name: Item_Weight, dtype: float64,
#  'FDN15': 2       17.5
#  759     17.5
#  4817    17.5
#  5074    17.5
#  6163    17.5
#  6952     NaN
#  8349     NaN
#  Name: Item_Weight, dtype: float64,
#  'FDX07': 3       19.2
#  1491    19.2
#  2459    19.2
#  3089    19.2
#  5906    19.2
#  7735     NaN
#  Name: Item_Weight, dtype: float64,
#  'NCD19': 4       8.93
#  522     8.93
#  802     8.93
#  2129    8.93
#  2907    8.93
#  3428    8.93
#  Name: Item_Weight, dtype: float64,
#  'FDP36': 5       10.395
#  1912    10.395
#  5685    10.395
#  Name: Item_Weight, dtype: float64,
#  'FDO10': 6       13.65
#  781     13.65
#  945     13.65
#  1576    13.65
#  4552      NaN
#  6802    13.65
#  8164      NaN
# ...
